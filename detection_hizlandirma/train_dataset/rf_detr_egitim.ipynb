# %%
# !pip install rfdetr
# !pip install pytorch_lightning
# !pip install faster-coco-eval
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rfdetr in /home/tom/.local/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: requests in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (2.32.5)
# Requirement already satisfied: torch>=2.2.0 in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (2.9.1+cu126)
# Requirement already satisfied: torchvision>=0.14.0 in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (0.24.1+cu126)
# Requirement already satisfied: tqdm in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (4.67.1)
# Requirement already satisfied: transformers<6.0.0,>=5.1.0 in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (5.3.0)
# Requirement already satisfied: peft in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (0.18.1)
# Requirement already satisfied: pydantic in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (2.12.4)
# Requirement already satisfied: supervision in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (0.27.0.post1)
# Requirement already satisfied: pyDeprecate<0.6,>=0.3 in /home/tom/.local/lib/python3.10/site-packages (from rfdetr) (0.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (1.7.2)
# Requirement already satisfied: numpy>=1.17 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (0.22.2)
# Requirement already satisfied: typer in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/tom/.local/lib/python3.10/site-packages (from transformers<6.0.0,>=5.1.0->rfdetr) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/tom/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/tom/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/tom/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tom/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/tom/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (4.15.0)
# Requirement already satisfied: anyio in /home/tom/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (4.11.0)
# Requirement already satisfied: certifi in /home/tom/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/tom/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (1.0.9)
# Requirement already satisfied: idna in /home/tom/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/tom/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (3.3)
# Requirement already satisfied: jinja2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (1.11.1.6)
# Requirement already satisfied: triton==3.5.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.2.0->rfdetr) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/tom/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.2.0->rfdetr) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/tom/.local/lib/python3.10/site-packages (from torchvision>=0.14.0->rfdetr) (12.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/tom/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/tom/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers<6.0.0,>=5.1.0->rfdetr) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tom/.local/lib/python3.10/site-packages (from jinja2->torch>=2.2.0->rfdetr) (3.0.3)
# Requirement already satisfied: psutil in /home/tom/.local/lib/python3.10/site-packages (from peft->rfdetr) (7.1.3)
# Requirement already satisfied: accelerate>=0.21.0 in /home/tom/.local/lib/python3.10/site-packages (from peft->rfdetr) (1.13.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tom/.local/lib/python3.10/site-packages (from pydantic->rfdetr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/tom/.local/lib/python3.10/site-packages (from pydantic->rfdetr) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/tom/.local/lib/python3.10/site-packages (from pydantic->rfdetr) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/tom/.local/lib/python3.10/site-packages (from requests->rfdetr) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->rfdetr) (1.26.5)
# Requirement already satisfied: scipy>=1.10.0 in /home/tom/.local/lib/python3.10/site-packages (from supervision->rfdetr) (1.15.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/tom/.local/lib/python3.10/site-packages (from supervision->rfdetr) (3.10.7)
# Requirement already satisfied: defusedxml>=0.7.1 in /home/tom/.local/lib/python3.10/site-packages (from supervision->rfdetr) (0.7.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /home/tom/.local/lib/python3.10/site-packages (from supervision->rfdetr) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib>=3.6.0->supervision->rfdetr) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision->rfdetr) (1.16.0)
# Requirement already satisfied: click>=8.2.1 in /home/tom/.local/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/tom/.local/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/tom/.local/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/tom/.local/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/tom/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=5.1.0->rfdetr) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/tom/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=5.1.0->rfdetr) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/tom/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=5.1.0->rfdetr) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /home/tom/.local/lib/python3.10/site-packages (from pytorch_lightning) (2.9.1+cu126)
# Requirement already satisfied: tqdm>=4.57.0 in /home/tom/.local/lib/python3.10/site-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /home/tom/.local/lib/python3.10/site-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/tom/.local/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.9.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging>=23.0 in /home/tom/.local/lib/python3.10/site-packages (from pytorch_lightning) (25.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /home/tom/.local/lib/python3.10/site-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohttp-3.13.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/tom/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tom/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading yarl-1.23.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: idna>=2.0 in /home/tom/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.7)
# Requirement already satisfied: filelock in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (3.25.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (1.11.1.6)
# Requirement already satisfied: triton==3.5.1 in /home/tom/.local/lib/python3.10/site-packages (from torch>=2.1.0->pytorch_lightning) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/tom/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /home/tom/.local/lib/python3.10/site-packages (from torchmetrics>0.7.0->pytorch_lightning) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tom/.local/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 1.1 MB/s  0:00:00m eta 0:00:01
# Downloading aiohttp-3.13.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.5 MB/s  0:00:01 eta 0:00:01
# Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
# Downloading yarl-1.23.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 2.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: propcache, multidict, lightning-utilities, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, torchmetrics, pytorch_lightning
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [pytorch_lightning]pytorch_lightning]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 frozenlist-1.8.0 lightning-utilities-0.15.3 multidict-6.7.1 propcache-0.4.1 pytorch_lightning-2.6.1 torchmetrics-1.9.0 yarl-1.23.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faster-coco-eval
#   Downloading faster_coco_eval-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /home/tom/.local/lib/python3.10/site-packages (from faster-coco-eval) (1.26.4)
# Downloading faster_coco_eval-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.2/578.2 kB 2.6 MB/s  0:00:00
# Installing collected packages: faster-coco-eval
# Successfully installed faster-coco-eval-1.7.2

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3uPfnGm9gdS5bDzJc9IL")
project = rf.workspace("egitim-blmkg").project("uav-detection-ewpzr-lvo9y")
version = project.version(8)
dataset = version.download("coco")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: roboflow in /home/tom/.local/lib/python3.10/site-packages (1.2.12)
# Requirement already satisfied: certifi in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (2025.11.12)
# Requirement already satisfied: idna==3.7 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (3.10.7)
# Requirement already satisfied: numpy>=1.18.5 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (12.0.0)
# Requirement already satisfied: pi-heif<2 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from roboflow) (1.16.0)
# Collecting urllib3>=1.26.6 (from roboflow)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/lib/python3/dist-packages (from roboflow) (0.9.1)
# Requirement already satisfied: filetype in /home/tom/.local/lib/python3.10/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/tom/.local/lib/python3.10/site-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/tom/.local/lib/python3.10/site-packages (from requests->roboflow) (3.4.4)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# label-studio 1.21.0 requires wheel<=0.40.0,>=0.38.1, but you have wheel 0.46.3 which is incompatible.
# Successfully installed urllib3-2.6.3
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/requests_toolbelt/_compat.py:48
#      47 try:
# ---> 48     from requests.packages.urllib3.contrib import appengine as gaecontrib
#      49 except ImportError:
#
# ImportError: cannot import name 'appengine' from 'requests.packages.urllib3.contrib' (/home/tom/.local/lib/python3.10/site-packages/urllib3/contrib/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().system('pip install roboflow')
# ----> 3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="3uPfnGm9gdS5bDzJc9IL")
#       5 project = rf.workspace("egitim-blmkg").project("uav-detection-ewpzr-lvo9y")
#
# File ~/.local/lib/python3.10/site-packages/roboflow/__init__.py:11
#       7 from urllib.parse import urlparse
#       9 import requests
# ---> 11 from roboflow.adapters import rfapi
#      12 from roboflow.config import API_URL, APP_URL, DEMO_KEYS, load_roboflow_api_key
#      13 from roboflow.core.project import Project
#
# File ~/.local/lib/python3.10/site-packages/roboflow/adapters/rfapi.py:8
#       6 import requests
#       7 from requests.exceptions import RequestException
# ----> 8 from requests_toolbelt.multipart.encoder import MultipartEncoder
#      10 from roboflow.config import API_URL, DEFAULT_BATCH_NAME, DEFAULT_JOB_NAME
#      11 from roboflow.util import image_utils
#
# File /usr/lib/python3/dist-packages/requests_toolbelt/__init__.py:12
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 requests-toolbelt
#       4 =================
#    (...)
#       9 :license: Apache v2.0, see LICENSE for more details
#      10 """
# ---> 12 from .adapters import SSLAdapter, SourceAddressAdapter
#      13 from .auth.guess import GuessAuth
#      14 from .multipart import (
#      15     MultipartEncoder, MultipartEncoderMonitor, MultipartDecoder,
#      16     ImproperBodyPartContentException, NonMultipartContentTypeException
#      17     )
#
# File /usr/lib/python3/dist-packages/requests_toolbelt/adapters/__init__.py:12
#       1 # -*- coding: utf-8 -*-
#       2 """
#       3 requests-toolbelt.adapters
#       4 ==========================
#    (...)
#       9 :license: Apache v2.0, see LICENSE for more details
#      10 """
# ---> 12 from .ssl import SSLAdapter
#      13 from .source import SourceAddressAdapter
#      15 __all__ = ['SSLAdapter', 'SourceAddressAdapter']
#
# File /usr/lib/python3/dist-packages/requests_toolbelt/adapters/ssl.py:16
#      12 import requests
#      14 from requests.adapters import HTTPAdapter
# ---> 16 from .._compat import poolmanager
#      19 class SSLAdapter(HTTPAdapter):
#      20     """
#      21     A HTTPS Adapter for Python Requests that allows the choice of the SSL/TLS
#      22     version negotiated by Requests. This can be used either to enforce the
#    (...)
#      43     properly when used with proxies.
#      44     """
#
# File /usr/lib/python3/dist-packages/requests_toolbelt/_compat.py:50
#      48         from requests.packages.urllib3.contrib import appengine as gaecontrib
#      49     except ImportError:
# ---> 50         from urllib3.contrib import appengine as gaecontrib
#      52 if requests.__build__ < 0x021200:
#      53     PyOpenSSLContext = None
#
# ImportError: cannot import name 'appengine' from 'urllib3.contrib' (/home/tom/.local/lib/python3.10/site-packages/urllib3/contrib/__init__.py)

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

model.train(
    dataset_dir="/content/UAV-Detection-6",
    epochs=100,
    batch_size=4,
    grad_accum_steps=4,
    lr=1e-4,
    output_dir="/content/output"
)
